# %% [markdown]
# # Anime Data Scraper

# %%
from jikanpy import Jikan
from ratelimiter import RateLimiter
import pandas as pd
from tqdm.notebook import tqdm

# %%
jikan = Jikan()  #Unofficial MAL API

try_anime_ids = list(range(40000))  # set of ids to request info for
savePath = 'animeData.csv'

## RATE LIMITING ##
# callsPerPeriod = 1
# PERIOD = 4          # in seconds
callsPerPeriod = 2
PERIOD = 1          # in seconds


@RateLimiter(max_calls=callsPerPeriod, period=PERIOD)
def get_anime(target_id):
    try:
        return jikan.anime(target_id)
    
    except:
        return None  # Handles case where anime id does not exist

# %%
anime_data = {
    'mal_id':[],
    'image_url':[],
    'title':[],
    'title_english':[],
    'title_japanese':[],
    'type':[],
    'episodes':[],
    'status':[],
    'rating':[],
    'score':[],
    'synopsis':[],
    'premiered':[],
    'broadcast':[],
    'genres':[]
}


# Request info from API
for aid in tqdm(try_anime_ids):
    anime_info = get_anime(aid)
    if anime_info != None:
        for field in anime_data.keys():
            if field == 'genres':
                genres = [genre_info['name'] for genre_info in anime_info[field]]
                anime_data[field].append(genres)
            else:
                anime_data[field].append(anime_info[field])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=40000.0), HTML(value='')))

# %%
# Convert to dataframe and save as csv
anime_df = pd.DataFrame.from_dict(anime_data)
anime_df.to_csv(savePath, index=False)

pd.set_option('display.max_columns', 500)
anime_df.head()
# Out:
#    mal_id                                          image_url  \
# 0       1  https://cdn.myanimelist.net/images/anime/4/196...
# 1       5  https://cdn.myanimelist.net/images/anime/1439/...
# 2       7  https://cdn.myanimelist.net/images/anime/1796/...
# 3       8  https://cdn.myanimelist.net/images/anime/7/215...
# 4      15  https://cdn.myanimelist.net/images/anime/12/66...
#
#                              title            title_english  \
# 0                     Cowboy Bebop             Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2               Witch Hunter Robin       Witch Hunter Robin
# 3                   Bouken Ou Beet   Beet the Vandel Buster
# 4                     Eyeshield 21                     None
#
#        title_japanese   type  episodes           status  \
# 0           カウボーイビバップ     TV      26.0  Finished Airing
# 1      カウボーイビバップ 天国の扉  Movie       1.0  Finished Airing
# 2  Witch Hunter ROBIN     TV      26.0  Finished Airing
# 3              冒険王ビィト     TV      52.0  Finished Airing
# 4            アイシールド21     TV     145.0  Finished Airing
#
#                            rating  score  \
# 0  R - 17+ (violence & profanity)   8.79
# 1  R - 17+ (violence & profanity)   8.39
# 2       PG-13 - Teens 13 or older   7.29
# 3                   PG - Children   6.99
# 4       PG-13 - Teens 13 or older   7.99
#
#                                             synopsis    premiered  \
# 0  In the year 2071, humanity has colonized sever...  Spring 1998
# 1  Another day, another bounty—such is the life o...         None
# 2  Witches are individuals with special powers li...  Summer 2002
# 3  It is the dark century and the people are suff...    Fall 2004
# 4  Sena is like any other shy kid starting high s...  Spring 2005
#
#                   broadcast                                             genres
# 0  Saturdays at 01:00 (JST)  [Action, Adventure, Comedy, Drama, Sci-Fi, Space]
# 1                      None            [Action, Drama, Mystery, Sci-Fi, Space]
# 2       Tuesdays at Unknown  [Action, Magic, Police, Supernatural, Drama, M...
# 3  Thursdays at 18:30 (JST)        [Adventure, Fantasy, Shounen, Supernatural]
# 4                   Unknown                  [Action, Sports, Comedy, Shounen]
